# %%
from transformers import pipeline
import torch

# %%
unmasker = pipeline('text-classification', model='facebook/xlm-roberta-xl')
# Out:
# Some weights of the model checkpoint at facebook/xlm-roberta-xl were not used when initializing XLMRobertaXLForSequenceClassification: ['lm_head.layer_norm.weight', 'lm_head.dense.weight', 'lm_head.layer_norm.bias', 'lm_head.dense.bias', 'lm_head.bias']
# - This IS expected if you are initializing XLMRobertaXLForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing XLMRobertaXLForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
# Contradiction
unmasker("И мы занимаемся этим уже на протяжении 85 лет. Мы только начали этим заниматься.")
# Out:
# XLMRobertaXLForSequenceClassification ===========================
# XLMRobertaXLModel ===========================
# XLMRobertaXLEmbeddings =============================================
# sssssssss 2 ==========================
# XLMRobertaXLEncoder ===================================
# XLMRobertaXLLayer================================
# XLMRobertaXLAttention ============================
# XLMRobertaXLSelfAttention===================
# XLMRobertaXLSelfOutput ==================================
# torch.Size([1, 19, 2560])
# torch.Size([1, 19, 2560])
# =======---=========
# XLMRobertaXLIntermediate ==================
# torch.Size([1, 19, 2560])
# XLMRobertaXLIntermediate middle==================
# torch.Size([1, 19, 10240])
# XLMRobertaXLIntermediate end==================
# XLMRobertaXLOutput ==========================
# torch.Size([1, 19, 2560])
# XLMRobertaXLLayer================================
# XLMRobertaXLAttention ============================
# ...

# %%
# Entailment
unmasker("You don’t have to stay there. You can leave.")
# Out:
# XLMRobertaXLForSequenceClassification ===========================
# XLMRobertaXLModel ===========================
# XLMRobertaXLEmbeddings =============================================
# sssssssss 2 ==========================
# XLMRobertaXLEncoder ===================================
# XLMRobertaXLLayer================================
# XLMRobertaXLAttention ============================
# XLMRobertaXLSelfAttention===================
# XLMRobertaXLSelfOutput ==================================
# torch.Size([1, 15, 2560])
# torch.Size([1, 15, 2560])
# =======---=========
# XLMRobertaXLIntermediate ==================
# torch.Size([1, 15, 2560])
# XLMRobertaXLIntermediate middle==================
# torch.Size([1, 15, 10240])
# XLMRobertaXLIntermediate end==================
# XLMRobertaXLOutput ==========================
# torch.Size([1, 15, 2560])
# XLMRobertaXLLayer================================
# XLMRobertaXLAttention ============================
# ...

# %%
# Neutral
unmasker("Während der Depression war es die ärmste Gegend, kurz vor dem Hungertod. Die Weltwirtschaftskrise dauerte mehr als zehn Jahre an.")
# Out:
# XLMRobertaXLForSequenceClassification ===========================
# XLMRobertaXLModel ===========================
# XLMRobertaXLEmbeddings =============================================
# sssssssss 2 ==========================
# XLMRobertaXLEncoder ===================================
# XLMRobertaXLLayer================================
# XLMRobertaXLAttention ============================
# XLMRobertaXLSelfAttention===================
# XLMRobertaXLSelfOutput ==================================
# torch.Size([1, 35, 2560])
# torch.Size([1, 35, 2560])
# =======---=========
# XLMRobertaXLIntermediate ==================
# torch.Size([1, 35, 2560])
# XLMRobertaXLIntermediate middle==================
# torch.Size([1, 35, 10240])
# XLMRobertaXLIntermediate end==================
# XLMRobertaXLOutput ==========================
# torch.Size([1, 35, 2560])
# XLMRobertaXLLayer================================
# XLMRobertaXLAttention ============================
# ...

# %%
from transformers import AutoTokenizer, AutoModelForMaskedLM

# %%
tokenizer = AutoTokenizer.from_pretrained('facebook/xlm-roberta-xl')
model = AutoModelForMaskedLM.from_pretrained("facebook/xlm-roberta-xl")

# %%
text = "Replace me by any text you'd like."
encoded_input = tokenizer(text, return_tensors='pt')

# %%
# forward pass
output = model(**encoded_input)
# Out:
# XLMRobertaXLModel ===========================
# XLMRobertaXLEmbeddings =============================================
# sssssssss 2 ==========================
# XLMRobertaXLEncoder ===================================
# XLMRobertaXLLayer================================
# XLMRobertaXLAttention ============================
# XLMRobertaXLSelfAttention===================
# XLMRobertaXLSelfOutput ==================================
# torch.Size([1, 13, 2560])
# torch.Size([1, 13, 2560])
# =======---=========
# XLMRobertaXLIntermediate ==================
# torch.Size([1, 13, 2560])
# XLMRobertaXLIntermediate middle==================
# torch.Size([1, 13, 10240])
# XLMRobertaXLIntermediate end==================
# XLMRobertaXLOutput ==========================
# torch.Size([1, 13, 2560])
# XLMRobertaXLLayer================================
# XLMRobertaXLAttention ============================
# XLMRobertaXLSelfAttention===================
# XLMRobertaXLSelfOutput ==================================
# ...

# %%
output
# Out:
# MaskedLMOutput(loss=None, logits=tensor([[[ 5.4955e+01, -7.3708e-01,  3.7740e+01,  ...,  1.4038e+00,
#            1.3047e+00,  1.2981e+01],
#          [ 1.6379e+01,  6.0185e-01,  4.9217e+01,  ...,  1.5384e+00,
#            3.8496e+00,  2.1121e+01],
#          [ 1.2713e+01, -4.9960e-02,  3.1936e+01,  ...,  2.1775e+00,
#            1.2648e+00,  1.4235e+01],
#          ...,
#          [ 2.2881e+01,  8.4277e-01,  4.3853e+01,  ...,  2.1066e+00,
#            1.1894e+00,  2.2515e+01],
#          [ 2.2142e+01,  2.1512e+00,  3.9792e+01,  ...,  1.0421e+00,
#            6.7496e-01,  2.0764e+01],
#          [ 1.1395e+01,  2.7462e+00,  5.1838e+01,  ...,  2.3704e+00,
#            6.3368e-01,  1.6416e+01]]], grad_fn=<AddBackward0>), hidden_states=None, attentions=None)
